# %%
import pandas as pd

df = pd.read_json("../../data/clean/main_datasets.json")

# %%
import random 
labels = ["ENTJ", "ENFJ", "ENTP"]
df = df.iloc[:100]
for i in labels:
    curr_df = df[df["mbti_result"] == i]
    tweets = curr_df["tweets"].apply(lambda x : " ".join(x[:4]))
    tweets = tweets.tolist()
    print(f"{i} :")
    for j in tweets:
        print(j)
    # print(tweets)
# Out:
# ENTJ :
# بنگاهی یا موبایل فروش تست فرانسوی من که تو اولین دیت بهترین رابطه ی عمرم گل گرفتم فردا آخرین فیلم دوره اول سینه کلوب رو معرفی میکنم به نظرتون اینکار رو ادامه بدم
# پس بیا دوتایی خاکش کنیم پاکن بیار اصلا پاکش کنیم این حاججججی گفتن و هییییییی گفتنش عالی بود تمام کل زندگیمون همینه همیشه یا نمیرسیم یا موقعی میرسیم که از ۱۰۰ تا برامون ۵ تا ارزش داره فازت چیه داداش با شما نبودم با اونایی که تو منشنا کصشر گفتن بودم
# ایول چ خوب منم خیلی خوشحالم بالاخره پاکش کردم منم این همه مدت بخاطر دوستام پاکش نمیکردم ولی دیدم یه گروه تو واتس اپ داریم پس اینجوری ازشون باخبرم امشب اینستاگرام رو پاک کردم و حقیقتا احساس میکنم بهترین تصمیمی بود که تو کل عمرم گرفتم میگذره ۲ آبان ۱۴۰۰
# ENFJ :
# چقدر واژه غریب است هجای تازه بیاور هنوز باورم نمیشهههه آقا شما فوق العاده این علی عظیمیییی ته کنسرت بهم گفت عزیزممممم عالیییی بودیییییی تینیدبتبتبتنببددیخصحنیدبتبککسدسذژایکسکدیمص
# امتحانام تموم شد بالاخره در این یه مورد به من گفتی که دل دریا کن ای دوست اگه آیلتس می خوای بخونی راه کارهاتو باهام شیر کن لطفا
# ...
